# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import lightgbm as lgb
import numpy as np
from sklearn.neural_network import MLPRegressor
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from tqdm import tqdm

# %% [markdown]
# Melting train data into long format

# %%
import pandas as pd

# Load the dataset
train = pd.read_parquet("train_data.parquet")  # update path if needed

# Identify IV and X columns
iv_columns = [col for col in train.columns if col.startswith('call_iv_') or col.startswith('put_iv_')]
x_columns = [f'X{i}' for i in range(42)]  # X0 to X41

# Melt IV columns into long format
iv_long = train.melt(
    id_vars=['timestamp', 'underlying', 'expiry'] + x_columns,
    value_vars=iv_columns,
    var_name='iv_type_strike',
    value_name='iv'
)

# Extract option type and strike price
iv_long['option_type'] = iv_long['iv_type_strike'].str.extract(r'(call|put)')
iv_long['strike_price'] = iv_long['iv_type_strike'].str.extract(r'_(\d+)$').astype(float) 

# Drop combined column and reorder
iv_long = iv_long.drop(columns=['iv_type_strike'])
iv_long = iv_long[['timestamp', 'underlying', 'expiry', 'option_type', 'strike_price', 'iv'] + x_columns]

# %% [markdown]
# Melting test data into long format

# %%
test = pd.read_parquet("test_data.parquet")

# Identify IV and X columns
iv_columns = [col for col in test.columns if col.startswith('call_iv_') or col.startswith('put_iv_')]
x_columns = [f'X{i}' for i in range(42)]  # X0 to X41

# Melt IV columns into long format
iv_long_test = test.melt(
    id_vars=[ 'underlying'] + x_columns,
    value_vars=iv_columns,
    var_name='iv_type_strike',
    value_name='iv'
)

# Extract option type and strike price
iv_long_test['option_type'] = iv_long_test['iv_type_strike'].str.extract(r'(call|put)')
iv_long_test['strike_price'] = iv_long_test['iv_type_strike'].str.extract(r'_(\d+)$').astype(float) 

# Drop combined column and reorder
iv_long_test = iv_long_test.drop(columns=['iv_type_strike'])
iv_long_test = iv_long_test[[ 'underlying', 'option_type', 'strike_price', 'iv'] + x_columns]

# %% [markdown]
# Adding extra features to train and test data

# %%
iv_long['moneyness'] = iv_long['strike_price'] / iv_long['underlying']
iv_long['strike_price']=iv_long['strike_price'] - iv_long['underlying']
iv_long['option_type']  = iv_long['option_type'].map({'call':1, 'put':-1})

iv_long_test['moneyness'] = iv_long_test['strike_price'] / iv_long_test['underlying']
iv_long_test['strike_price']=iv_long_test['strike_price'] - iv_long_test['underlying']
iv_long_test['option_type']  = iv_long_test['option_type'].map({'call':1, 'put':-1})

# %%
feature_columns = [f'X{i}' for i in range(42)]
feature_columns.append('strike_price')
feature_columns.append('moneyness')
feature_columns.append('option_type')

feature_columns_test = [f'X{i}' for i in range(42)]
feature_columns_test.append('strike_price')
feature_columns_test.append('moneyness')
feature_columns_test.append('option_type')

# %%
iv_long_cleaned = iv_long[(iv_long['iv'] < 1) & (iv_long['iv'] > 0)].copy()

# %% [markdown]
# Scaling train(features and target) and test(only features)

# %%
train_scaled_df = iv_long_cleaned.copy()

test_scaled_df = iv_long_test.copy()

# %% [markdown]
# Splitting test data into validation and submission

# %%
# Split based on whether 'iv' is NaN
submission_df = test_scaled_df[test_scaled_df['iv'].isna()]
test_df = test_scaled_df[test_scaled_df['iv'].notna()]

# %%
CORRELATION_THRESHOLD = 0.8

# %% [markdown]
# ### Removing feature with high avg and corr>0.80 with specific feature

# %%
correlation_matrix = train_scaled_df[feature_columns].corr().abs()

# Step 2: Compute average correlation for each feature (excluding self-correlation)
avg_corr = correlation_matrix.apply(lambda x: (x.sum() - 1) / (len(x) - 1), axis=1)

# Step 3: Get top 10 features with highest average correlation
top_10_high_avg_corr = avg_corr.sort_values(ascending=False).head(10)

# Step 4: Find features among top 10 that have correlation > 0.80 with **any** other feature
features_to_drop = []
for feature in top_10_high_avg_corr.index:
    # Drop self-correlation and check if any other correlation is > 0.80
    high_corr_features = correlation_matrix[feature][correlation_matrix[feature] > 0.80].drop(labels=feature)
    if not high_corr_features.empty:
        features_to_drop.append(feature)

# Output features to drop
print("Dropping features due to high average and pairwise correlation:", features_to_drop)

# Optional: Drop from your dataset
train_scaled_df_dropped = train_scaled_df.drop(columns=features_to_drop)
test_scaled_df_dropped = test_df.drop(columns=features_to_drop)
submission_df_dropped = submission_df.drop(columns=features_to_drop)
# Out:
# Dropping features due to high average and pairwise correlation: ['X1', 'X38', 'X29', 'X16', 'X28']

# %%
print(iv_long[feature_columns].shape)
print(iv_long_test[feature_columns_test].shape)
print(train_scaled_df.shape)
print(train_scaled_df_dropped.shape)
print(test_df.shape)
print(test_scaled_df_dropped.shape)
# Out:
# (9273680, 45)
# (627380, 45)
# (8770739, 49)
# (8770739, 44)
# (250876, 47)
# (250876, 42)

# %% [markdown]
# TRAINING

# %%
#train 
train_dataset1 = train_scaled_df_dropped.drop(columns=['iv','timestamp', 'underlying', 'expiry'])
train_dataset2 = train_scaled_df.drop(columns=['iv','timestamp', 'underlying', 'expiry'])
train_target = train_scaled_df['iv']

#test
test_dataset1 = test_scaled_df_dropped.drop(columns=['iv', 'underlying'])
test_dataset2 = test_df.drop(columns=['iv', 'underlying'])
test_target = test_df['iv']

#submission
submission_dataset1 = submission_df_dropped.drop(columns=['iv', 'underlying'])
submission_dataset2 = submission_df.drop(columns=['iv', 'underlying'])

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler


df = train_dataset2.copy()
df_test = test_dataset2.copy()
df1 = train_dataset1.copy()
df_test1 = test_dataset1.copy()
df_submission2 = submission_dataset2.copy()
df_submission1 = submission_dataset1.copy()

categorical_cols = ['option_type']

numeric_cols1 = [col for col in df.columns if col not in (categorical_cols) + (features_to_drop)]
numeric_cols = [col for col in df.columns if col not in (categorical_cols) ]

# %%
scaler = MinMaxScaler()

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df_test[numeric_cols] = scaler.fit_transform(df_test[numeric_cols])

df1[numeric_cols1] = scaler.fit_transform(df1[numeric_cols1])
df_test1[numeric_cols1] = scaler.fit_transform(df_test1[numeric_cols1])

df_submission2[numeric_cols] = scaler.fit_transform(df_submission2[numeric_cols])
df_submission1[numeric_cols1] = scaler.fit_transform(df_submission1[numeric_cols1])

# %%
import numpy as np

selected_cols = ['strike_price', 'moneyness', 'option_type']

# Train
X_train1 = df1.to_numpy(dtype=np.float32)
X_train2 = df.to_numpy(dtype=np.float32)
y_train = train_target.to_numpy(dtype=np.float32).reshape(-1, 1)  # Make it (N,1) for regression

# Test
X_test1 = df_test1.to_numpy(dtype=np.float32)
X_test2 = df_test.to_numpy(dtype=np.float32)
y_test = test_target.to_numpy(dtype=np.float32).reshape(-1, 1)    # Optional if test_target exists

#submission
X_submission1 = df_submission1.to_numpy(dtype=np.float32)
X_submission2 = df_submission2.to_numpy(dtype=np.float32)



#hybrid
selected_cols = ['strike_price', 'moneyness', 'option_type']

# Train
X_train3 = df_test1[selected_cols].to_numpy(dtype=np.float32)


# Submission
X_submission3 = df_submission1[selected_cols].to_numpy(dtype=np.float32)

# %%
import importlib
import model  # ensure model is imported
importlib.reload(model)
from model import Trainer

# %%
trainer = Trainer(
    input_dim=X_test2.shape[1],  # number of features
    learning_rate=0.001,
    batch_size=2048,
    epochs=500
)

# Train the model
trainer.train(X_test2, y_test)
# Out:
# [INFO] Training on device: cuda
# [INFO] X_tensor shape: torch.Size([250876, 45])
# [INFO] y_tensor shape: torch.Size([250876, 1])
#
# [INFO] Epoch 1/500
# [DEBUG] First batch X shape: torch.Size([2048, 45])
# [DEBUG] First batch y shape: torch.Size([2048, 1])
#  Epoch 1 completed. Total Loss: 0.4273
#
# [INFO] Epoch 2/500
#  Epoch 2 completed. Total Loss: 0.2280
#
# [INFO] Epoch 3/500
#  Epoch 3 completed. Total Loss: 0.2082
#
# [INFO] Epoch 4/500
#  Epoch 4 completed. Total Loss: 0.1978
#
# [INFO] Epoch 5/500
#  Epoch 5 completed. Total Loss: 0.1902
#
# [INFO] Epoch 6/500
#  Epoch 6 completed. Total Loss: 0.1872
#
# [INFO] Epoch 7/500
#  Epoch 7 completed. Total Loss: 0.1833
#
# [INFO] Epoch 8/500
#  Epoch 8 completed. Total Loss: 0.1808
#
# [INFO] Epoch 9/500
#  Epoch 9 completed. Total Loss: 0.1774
#
# [INFO] Epoch 10/500
#  Epoch 10 completed. Total Loss: 0.1745
#
# [INFO] Epoch 11/500
#  Epoch 11 completed. Total Loss: 0.1728
#
# [INFO] Epoch 12/500
#  Epoch 12 completed. Total Loss: 0.1702
#
# [INFO] Epoch 13/500
#  Epoch 13 completed. Total Loss: 0.1678
#
# [INFO] Epoch 14/500
#  Epoch 14 completed. Total Loss: 0.1663
#
# [INFO] Epoch 15/500
#  Epoch 15 completed. Total Loss: 0.1656
#
# [INFO] Epoch 16/500
#  Epoch 16 completed. Total Loss: 0.1623
#
# [INFO] Epoch 17/500
#  Epoch 17 completed. Total Loss: 0.1610
#
# [INFO] Epoch 18/500
#  Epoch 18 completed. Total Loss: 0.1605
#
# [INFO] Epoch 19/500
#  Epoch 19 completed. Total Loss: 0.1590
#
# [INFO] Epoch 20/500
#  Epoch 20 completed. Total Loss: 0.1584
#
# [INFO] Epoch 21/500
#  Epoch 21 completed. Total Loss: 0.1567
#
# [INFO] Epoch 22/500
#  Epoch 22 completed. Total Loss: 0.1557
#
# [INFO] Epoch 23/500
#  Epoch 23 completed. Total Loss: 0.1545
#
# [INFO] Epoch 24/500
#  Epoch 24 completed. Total Loss: 0.1533
#
# [INFO] Epoch 25/500
#  Epoch 25 completed. Total Loss: 0.1527
#
# [INFO] Epoch 26/500
#  Epoch 26 completed. Total Loss: 0.1520
#
# [INFO] Epoch 27/500
#  Epoch 27 completed. Total Loss: 0.1504
#
# [INFO] Epoch 28/500
#  Epoch 28 completed. Total Loss: 0.1499
#
# [INFO] Epoch 29/500
#  Epoch 29 completed. Total Loss: 0.1501
#
# [INFO] Epoch 30/500
#  Epoch 30 completed. Total Loss: 0.1488
#
# [INFO] Epoch 31/500
#  Epoch 31 completed. Total Loss: 0.1475
#
# [INFO] Epoch 32/500
#  Epoch 32 completed. Total Loss: 0.1475
#
# [INFO] Epoch 33/500
#  Epoch 33 completed. Total Loss: 0.1468
#
# [INFO] Epoch 34/500
#  Epoch 34 completed. Total Loss: 0.1464
#
# [INFO] Epoch 35/500
#  Epoch 35 completed. Total Loss: 0.1456
#
# [INFO] Epoch 36/500
#  Epoch 36 completed. Total Loss: 0.1450
#
# [INFO] Epoch 37/500
#  Epoch 37 completed. Total Loss: 0.1444
#
# [INFO] Epoch 38/500
#  Epoch 38 completed. Total Loss: 0.1428
#
# [INFO] Epoch 39/500
#  Epoch 39 completed. Total Loss: 0.1430
#
# [INFO] Epoch 40/500
#  Epoch 40 completed. Total Loss: 0.1426
#
# [INFO] Epoch 41/500
#  Epoch 41 completed. Total Loss: 0.1418
#
# [INFO] Epoch 42/500
#  Epoch 42 completed. Total Loss: 0.1422
#
# [INFO] Epoch 43/500
#  Epoch 43 completed. Total Loss: 0.1408
#
# [INFO] Epoch 44/500
#  Epoch 44 completed. Total Loss: 0.1397
#
# [INFO] Epoch 45/500
#  Epoch 45 completed. Total Loss: 0.1393
#
# [INFO] Epoch 46/500
#  Epoch 46 completed. Total Loss: 0.1395
#
# [INFO] Epoch 47/500
#  Epoch 47 completed. Total Loss: 0.1385
#
# [INFO] Epoch 48/500
#  Epoch 48 completed. Total Loss: 0.1373
#
# [INFO] Epoch 49/500
#  Epoch 49 completed. Total Loss: 0.1375
#
# [INFO] Epoch 50/500
#  Epoch 50 completed. Total Loss: 0.1365
#
# [INFO] Epoch 51/500
#  Epoch 51 completed. Total Loss: 0.1363
#
# [INFO] Epoch 52/500
#  Epoch 52 completed. Total Loss: 0.1354
#
# [INFO] Epoch 53/500
#  Epoch 53 completed. Total Loss: 0.1354
#
# [INFO] Epoch 54/500
#  Epoch 54 completed. Total Loss: 0.1339
#
# [INFO] Epoch 55/500
#  Epoch 55 completed. Total Loss: 0.1333
#
# [INFO] Epoch 56/500
#  Epoch 56 completed. Total Loss: 0.1335
#
# [INFO] Epoch 57/500
#  Epoch 57 completed. Total Loss: 0.1329
#
# [INFO] Epoch 58/500
#  Epoch 58 completed. Total Loss: 0.1328
#
# [INFO] Epoch 59/500
#  Epoch 59 completed. Total Loss: 0.1311
#
# [INFO] Epoch 60/500
#  Epoch 60 completed. Total Loss: 0.1311
#
# [INFO] Epoch 61/500
#  Epoch 61 completed. Total Loss: 0.1304
#
# [INFO] Epoch 62/500
#  Epoch 62 completed. Total Loss: 0.1292
#
# [INFO] Epoch 63/500
#  Epoch 63 completed. Total Loss: 0.1280
#
# [INFO] Epoch 64/500
#  Epoch 64 completed. Total Loss: 0.1269
#
# [INFO] Epoch 65/500
#  Epoch 65 completed. Total Loss: 0.1245
#
# [INFO] Epoch 66/500
#  Epoch 66 completed. Total Loss: 0.1232
#
# [INFO] Epoch 67/500
#  Epoch 67 completed. Total Loss: 0.1220
#
# [INFO] Epoch 68/500
#  Epoch 68 completed. Total Loss: 0.1217
#
# [INFO] Epoch 69/500
#  Epoch 69 completed. Total Loss: 0.1209
#
# [INFO] Epoch 70/500
#  Epoch 70 completed. Total Loss: 0.1194
#
# [INFO] Epoch 71/500
#  Epoch 71 completed. Total Loss: 0.1192
#
# [INFO] Epoch 72/500
#  Epoch 72 completed. Total Loss: 0.1191
#
# [INFO] Epoch 73/500
#  Epoch 73 completed. Total Loss: 0.1181
#
# [INFO] Epoch 74/500
#  Epoch 74 completed. Total Loss: 0.1179
#
# [INFO] Epoch 75/500
#  Epoch 75 completed. Total Loss: 0.1167
#
# [INFO] Epoch 76/500
#  Epoch 76 completed. Total Loss: 0.1161
#
# [INFO] Epoch 77/500
#  Epoch 77 completed. Total Loss: 0.1157
#
# [INFO] Epoch 78/500
#  Epoch 78 completed. Total Loss: 0.1153
#
# [INFO] Epoch 79/500
#  Epoch 79 completed. Total Loss: 0.1141
#
# [INFO] Epoch 80/500
#  Epoch 80 completed. Total Loss: 0.1136
#
# [INFO] Epoch 81/500
#  Epoch 81 completed. Total Loss: 0.1136
#
# [INFO] Epoch 82/500
#  Epoch 82 completed. Total Loss: 0.1127
#
# [INFO] Epoch 83/500
#  Epoch 83 completed. Total Loss: 0.1114
#
# [INFO] Epoch 84/500
#  Epoch 84 completed. Total Loss: 0.1108
#
# [INFO] Epoch 85/500
#  Epoch 85 completed. Total Loss: 0.1098
#
# [INFO] Epoch 86/500
#  Epoch 86 completed. Total Loss: 0.1098
#
# [INFO] Epoch 87/500
#  Epoch 87 completed. Total Loss: 0.1088
#
# [INFO] Epoch 88/500
#  Epoch 88 completed. Total Loss: 0.1085
#
# [INFO] Epoch 89/500
#  Epoch 89 completed. Total Loss: 0.1071
#
# [INFO] Epoch 90/500
#  Epoch 90 completed. Total Loss: 0.1082
#
# [INFO] Epoch 91/500
#  Epoch 91 completed. Total Loss: 0.1077
#
# [INFO] Epoch 92/500
#  Epoch 92 completed. Total Loss: 0.1065
#
# [INFO] Epoch 93/500
#  Epoch 93 completed. Total Loss: 0.1063
#
# [INFO] Epoch 94/500
#  Epoch 94 completed. Total Loss: 0.1058
#
# [INFO] Epoch 95/500
#  Epoch 95 completed. Total Loss: 0.1058
#
# [INFO] Epoch 96/500
#  Epoch 96 completed. Total Loss: 0.1048
#
# [INFO] Epoch 97/500
#  Epoch 97 completed. Total Loss: 0.1045
#
# [INFO] Epoch 98/500
#  Epoch 98 completed. Total Loss: 0.1045
#
# [INFO] Epoch 99/500
#  Epoch 99 completed. Total Loss: 0.1023
#
# [INFO] Epoch 100/500
#  Epoch 100 completed. Total Loss: 0.1024
#
# [INFO] Epoch 101/500
#  Epoch 101 completed. Total Loss: 0.1016
#
# [INFO] Epoch 102/500
#  Epoch 102 completed. Total Loss: 0.1016
#
# [INFO] Epoch 103/500
#  Epoch 103 completed. Total Loss: 0.1000
#
# [INFO] Epoch 104/500
#  Epoch 104 completed. Total Loss: 0.0989
#
# [INFO] Epoch 105/500
#  Epoch 105 completed. Total Loss: 0.0977
#
# [INFO] Epoch 106/500
#  Epoch 106 completed. Total Loss: 0.0986
#
# [INFO] Epoch 107/500
#  Epoch 107 completed. Total Loss: 0.0972
#
# [INFO] Epoch 108/500
#  Epoch 108 completed. Total Loss: 0.0959
#
# [INFO] Epoch 109/500
#  Epoch 109 completed. Total Loss: 0.0953
#
# [INFO] Epoch 110/500
#  Epoch 110 completed. Total Loss: 0.0953
#
# [INFO] Epoch 111/500
#  Epoch 111 completed. Total Loss: 0.0942
#
# [INFO] Epoch 112/500
#  Epoch 112 completed. Total Loss: 0.0938
#
# [INFO] Epoch 113/500
#  Epoch 113 completed. Total Loss: 0.0934
#
# [INFO] Epoch 114/500
#  Epoch 114 completed. Total Loss: 0.0925
#
# [INFO] Epoch 115/500
#  Epoch 115 completed. Total Loss: 0.0915
#
# [INFO] Epoch 116/500
#  Epoch 116 completed. Total Loss: 0.0922
#
# [INFO] Epoch 117/500
#  Epoch 117 completed. Total Loss: 0.0922
#
# [INFO] Epoch 118/500
#  Epoch 118 completed. Total Loss: 0.0913
#
# [INFO] Epoch 119/500
#  Epoch 119 completed. Total Loss: 0.0909
#
# [INFO] Epoch 120/500
#  Epoch 120 completed. Total Loss: 0.0911
#
# [INFO] Epoch 121/500
#  Epoch 121 completed. Total Loss: 0.0910
#
# [INFO] Epoch 122/500
#  Epoch 122 completed. Total Loss: 0.0901
#
# [INFO] Epoch 123/500
#  Epoch 123 completed. Total Loss: 0.0899
#
# [INFO] Epoch 124/500
#  Epoch 124 completed. Total Loss: 0.0884
#
# [INFO] Epoch 125/500
#  Epoch 125 completed. Total Loss: 0.0886
#
# [INFO] Epoch 126/500
#  Epoch 126 completed. Total Loss: 0.0874
#
# [INFO] Epoch 127/500
#  Epoch 127 completed. Total Loss: 0.0870
#
# [INFO] Epoch 128/500
#  Epoch 128 completed. Total Loss: 0.0873
#
# [INFO] Epoch 129/500
#  Epoch 129 completed. Total Loss: 0.0855
#
# [INFO] Epoch 130/500
#  Epoch 130 completed. Total Loss: 0.0858
#
# [INFO] Epoch 131/500
#  Epoch 131 completed. Total Loss: 0.0857
#
# [INFO] Epoch 132/500
#  Epoch 132 completed. Total Loss: 0.0862
#
# [INFO] Epoch 133/500
#  Epoch 133 completed. Total Loss: 0.0854
#
# [INFO] Epoch 134/500
#  Epoch 134 completed. Total Loss: 0.0857
#
# [INFO] Epoch 135/500
#  Epoch 135 completed. Total Loss: 0.0850
#
# [INFO] Epoch 136/500
#  Epoch 136 completed. Total Loss: 0.0847
#
# [INFO] Epoch 137/500
#  Epoch 137 completed. Total Loss: 0.0847
#
# [INFO] Epoch 138/500
#  Epoch 138 completed. Total Loss: 0.0835
#
# [INFO] Epoch 139/500
#  Epoch 139 completed. Total Loss: 0.0835
#
# [INFO] Epoch 140/500
#  Epoch 140 completed. Total Loss: 0.0831
#
# [INFO] Epoch 141/500
#  Epoch 141 completed. Total Loss: 0.0824
#
# [INFO] Epoch 142/500
#  Epoch 142 completed. Total Loss: 0.0824
#
# [INFO] Epoch 143/500
#  Epoch 143 completed. Total Loss: 0.0830
#
# [INFO] Epoch 144/500
#  Epoch 144 completed. Total Loss: 0.0819
#
# [INFO] Epoch 145/500
#  Epoch 145 completed. Total Loss: 0.0817
#
# [INFO] Epoch 146/500
#  Epoch 146 completed. Total Loss: 0.0807
#
# [INFO] Epoch 147/500
#  Epoch 147 completed. Total Loss: 0.0811
#
# [INFO] Epoch 148/500
#  Epoch 148 completed. Total Loss: 0.0802
#
# [INFO] Epoch 149/500
#  Epoch 149 completed. Total Loss: 0.0796
#
# [INFO] Epoch 150/500
#  Epoch 150 completed. Total Loss: 0.0803
#
# [INFO] Epoch 151/500
#  Epoch 151 completed. Total Loss: 0.0806
#
# [INFO] Epoch 152/500
#  Epoch 152 completed. Total Loss: 0.0794
#
# [INFO] Epoch 153/500
#  Epoch 153 completed. Total Loss: 0.0796
#
# [INFO] Epoch 154/500
#  Epoch 154 completed. Total Loss: 0.0790
#
# [INFO] Epoch 155/500
#  Epoch 155 completed. Total Loss: 0.0790
#
# [INFO] Epoch 156/500
#  Epoch 156 completed. Total Loss: 0.0790
#
# [INFO] Epoch 157/500
#  Epoch 157 completed. Total Loss: 0.0786
#
# [INFO] Epoch 158/500
#  Epoch 158 completed. Total Loss: 0.0782
#
# [INFO] Epoch 159/500
#  Epoch 159 completed. Total Loss: 0.0780
#
# [INFO] Epoch 160/500
#  Epoch 160 completed. Total Loss: 0.0782
#
# [INFO] Epoch 161/500
#  Epoch 161 completed. Total Loss: 0.0784
#
# [INFO] Epoch 162/500
#  Epoch 162 completed. Total Loss: 0.0786
#
# [INFO] Epoch 163/500
#  Epoch 163 completed. Total Loss: 0.0775
#
# [INFO] Epoch 164/500
#  Epoch 164 completed. Total Loss: 0.0768
#
# [INFO] Epoch 165/500
#  Epoch 165 completed. Total Loss: 0.0777
#
# [INFO] Epoch 166/500
#  Epoch 166 completed. Total Loss: 0.0767
#
# [INFO] Epoch 167/500
#  Epoch 167 completed. Total Loss: 0.0769
#
# [INFO] Epoch 168/500
#  Epoch 168 completed. Total Loss: 0.0769
#
# [INFO] Epoch 169/500
#  Epoch 169 completed. Total Loss: 0.0763
#
# [INFO] Epoch 170/500
#  Epoch 170 completed. Total Loss: 0.0759
#
# [INFO] Epoch 171/500
#  Epoch 171 completed. Total Loss: 0.0754
#
# [INFO] Epoch 172/500
#  Epoch 172 completed. Total Loss: 0.0758
#
# [INFO] Epoch 173/500
#  Epoch 173 completed. Total Loss: 0.0749
#
# [INFO] Epoch 174/500
#  Epoch 174 completed. Total Loss: 0.0765
#
# [INFO] Epoch 175/500
#  Epoch 175 completed. Total Loss: 0.0754
#
# [INFO] Epoch 176/500
#  Epoch 176 completed. Total Loss: 0.0760
#
# [INFO] Epoch 177/500
#  Epoch 177 completed. Total Loss: 0.0754
#
# [INFO] Epoch 178/500
#  Epoch 178 completed. Total Loss: 0.0746
#
# [INFO] Epoch 179/500
#  Epoch 179 completed. Total Loss: 0.0745
#
# [INFO] Epoch 180/500
#  Epoch 180 completed. Total Loss: 0.0751
#
# [INFO] Epoch 181/500
#  Epoch 181 completed. Total Loss: 0.0753
#
# [INFO] Epoch 182/500
#  Epoch 182 completed. Total Loss: 0.0745
#
# [INFO] Epoch 183/500
#  Epoch 183 completed. Total Loss: 0.0740
#
# [INFO] Epoch 184/500
#  Epoch 184 completed. Total Loss: 0.0749
#
# [INFO] Epoch 185/500
#  Epoch 185 completed. Total Loss: 0.0739
#
# [INFO] Epoch 186/500
#  Epoch 186 completed. Total Loss: 0.0743
#
# [INFO] Epoch 187/500
#  Epoch 187 completed. Total Loss: 0.0742
#
# [INFO] Epoch 188/500
#  Epoch 188 completed. Total Loss: 0.0738
#
# [INFO] Epoch 189/500
#  Epoch 189 completed. Total Loss: 0.0747
#
# [INFO] Epoch 190/500
#  Epoch 190 completed. Total Loss: 0.0742
#
# [INFO] Epoch 191/500
#  Epoch 191 completed. Total Loss: 0.0729
#
# [INFO] Epoch 192/500
#  Epoch 192 completed. Total Loss: 0.0734
#
# [INFO] Epoch 193/500
#  Epoch 193 completed. Total Loss: 0.0731
#
# [INFO] Epoch 194/500
#  Epoch 194 completed. Total Loss: 0.0734
#
# [INFO] Epoch 195/500
#  Epoch 195 completed. Total Loss: 0.0730
#
# [INFO] Epoch 196/500
#  Epoch 196 completed. Total Loss: 0.0723
#
# [INFO] Epoch 197/500
#  Epoch 197 completed. Total Loss: 0.0728
#
# [INFO] Epoch 198/500
#  Epoch 198 completed. Total Loss: 0.0733
#
# [INFO] Epoch 199/500
#  Epoch 199 completed. Total Loss: 0.0724
#
# [INFO] Epoch 200/500
#  Epoch 200 completed. Total Loss: 0.0723
#
# [INFO] Epoch 201/500
#  Epoch 201 completed. Total Loss: 0.0722
#
# [INFO] Epoch 202/500
#  Epoch 202 completed. Total Loss: 0.0728
#
# [INFO] Epoch 203/500
#  Epoch 203 completed. Total Loss: 0.0723
#
# [INFO] Epoch 204/500
#  Epoch 204 completed. Total Loss: 0.0710
#
# [INFO] Epoch 205/500
#  Epoch 205 completed. Total Loss: 0.0713
#
# [INFO] Epoch 206/500
#  Epoch 206 completed. Total Loss: 0.0722
#
# [INFO] Epoch 207/500
#  Epoch 207 completed. Total Loss: 0.0717
#
# [INFO] Epoch 208/500
#  Epoch 208 completed. Total Loss: 0.0717
#
# [INFO] Epoch 209/500
#  Epoch 209 completed. Total Loss: 0.0710
#
# [INFO] Epoch 210/500
#  Epoch 210 completed. Total Loss: 0.0725
#
# [INFO] Epoch 211/500
#  Epoch 211 completed. Total Loss: 0.0711
#
# [INFO] Epoch 212/500
#  Epoch 212 completed. Total Loss: 0.0711
#
# [INFO] Epoch 213/500
#  Epoch 213 completed. Total Loss: 0.0705
#
# [INFO] Epoch 214/500
#  Epoch 214 completed. Total Loss: 0.0707
#
# [INFO] Epoch 215/500
#  Epoch 215 completed. Total Loss: 0.0701
#
# [INFO] Epoch 216/500
#  Epoch 216 completed. Total Loss: 0.0705
#
# [INFO] Epoch 217/500
#  Epoch 217 completed. Total Loss: 0.0707
#
# [INFO] Epoch 218/500
#  Epoch 218 completed. Total Loss: 0.0701
#
# [INFO] Epoch 219/500
#  Epoch 219 completed. Total Loss: 0.0699
#
# [INFO] Epoch 220/500
#  Epoch 220 completed. Total Loss: 0.0701
#
# [INFO] Epoch 221/500
#  Epoch 221 completed. Total Loss: 0.0697
#
# [INFO] Epoch 222/500
#  Epoch 222 completed. Total Loss: 0.0701
#
# [INFO] Epoch 223/500
#  Epoch 223 completed. Total Loss: 0.0689
#
# [INFO] Epoch 224/500
#  Epoch 224 completed. Total Loss: 0.0692
#
# [INFO] Epoch 225/500
#  Epoch 225 completed. Total Loss: 0.0693
#
# [INFO] Epoch 226/500
#  Epoch 226 completed. Total Loss: 0.0691
#
# [INFO] Epoch 227/500
#  Epoch 227 completed. Total Loss: 0.0701
#
# [INFO] Epoch 228/500
#  Epoch 228 completed. Total Loss: 0.0697
#
# [INFO] Epoch 229/500
#  Epoch 229 completed. Total Loss: 0.0690
#
# [INFO] Epoch 230/500
#  Epoch 230 completed. Total Loss: 0.0683
#
# [INFO] Epoch 231/500
#  Epoch 231 completed. Total Loss: 0.0697
#
# [INFO] Epoch 232/500
#  Epoch 232 completed. Total Loss: 0.0684
#
# [INFO] Epoch 233/500
#  Epoch 233 completed. Total Loss: 0.0697
#
# [INFO] Epoch 234/500
#  Epoch 234 completed. Total Loss: 0.0683
#
# [INFO] Epoch 235/500
#  Epoch 235 completed. Total Loss: 0.0689
#
# [INFO] Epoch 236/500
#  Epoch 236 completed. Total Loss: 0.0690
#
# [INFO] Epoch 237/500
#  Epoch 237 completed. Total Loss: 0.0687
#
# [INFO] Epoch 238/500
#  Epoch 238 completed. Total Loss: 0.0688
#
# [INFO] Epoch 239/500
#  Epoch 239 completed. Total Loss: 0.0680
#
# [INFO] Epoch 240/500
#  Epoch 240 completed. Total Loss: 0.0679
#
# [INFO] Epoch 241/500
#  Epoch 241 completed. Total Loss: 0.0684
#
# [INFO] Epoch 242/500
#  Epoch 242 completed. Total Loss: 0.0679
#
# [INFO] Epoch 243/500
#  Epoch 243 completed. Total Loss: 0.0688
#
# [INFO] Epoch 244/500
#  Epoch 244 completed. Total Loss: 0.0679
#
# [INFO] Epoch 245/500
#  Epoch 245 completed. Total Loss: 0.0678
#
# [INFO] Epoch 246/500
#  Epoch 246 completed. Total Loss: 0.0680
#
# [INFO] Epoch 247/500
#  Epoch 247 completed. Total Loss: 0.0677
#
# [INFO] Epoch 248/500
#  Epoch 248 completed. Total Loss: 0.0677
#
# [INFO] Epoch 249/500
#  Epoch 249 completed. Total Loss: 0.0676
#
# [INFO] Epoch 250/500
#  Epoch 250 completed. Total Loss: 0.0679
#
# [INFO] Epoch 251/500
#  Epoch 251 completed. Total Loss: 0.0674
#
# [INFO] Epoch 252/500
#  Epoch 252 completed. Total Loss: 0.0666
#
# [INFO] Epoch 253/500
#  Epoch 253 completed. Total Loss: 0.0665
#
# [INFO] Epoch 254/500
#  Epoch 254 completed. Total Loss: 0.0671
#
# [INFO] Epoch 255/500
#  Epoch 255 completed. Total Loss: 0.0673
#
# [INFO] Epoch 256/500
#  Epoch 256 completed. Total Loss: 0.0666
#
# [INFO] Epoch 257/500
#  Epoch 257 completed. Total Loss: 0.0672
#
# [INFO] Epoch 258/500
#  Epoch 258 completed. Total Loss: 0.0664
#
# [INFO] Epoch 259/500
#  Epoch 259 completed. Total Loss: 0.0675
#
# [INFO] Epoch 260/500
#  Epoch 260 completed. Total Loss: 0.0668
#
# [INFO] Epoch 261/500
#  Epoch 261 completed. Total Loss: 0.0665
#
# [INFO] Epoch 262/500
#  Epoch 262 completed. Total Loss: 0.0660
#
# [INFO] Epoch 263/500
#  Epoch 263 completed. Total Loss: 0.0651
#
# [INFO] Epoch 264/500
#  Epoch 264 completed. Total Loss: 0.0662
#
# [INFO] Epoch 265/500
#  Epoch 265 completed. Total Loss: 0.0662
#
# [INFO] Epoch 266/500
#  Epoch 266 completed. Total Loss: 0.0660
#
# [INFO] Epoch 267/500
#  Epoch 267 completed. Total Loss: 0.0656
#
# [INFO] Epoch 268/500
#  Epoch 268 completed. Total Loss: 0.0659
#
# [INFO] Epoch 269/500
#  Epoch 269 completed. Total Loss: 0.0663
#
# [INFO] Epoch 270/500
#  Epoch 270 completed. Total Loss: 0.0668
#
# [INFO] Epoch 271/500
#  Epoch 271 completed. Total Loss: 0.0663
#
# [INFO] Epoch 272/500
#  Epoch 272 completed. Total Loss: 0.0667
#
# [INFO] Epoch 273/500
#  Epoch 273 completed. Total Loss: 0.0658
#
# [INFO] Epoch 274/500
#  Epoch 274 completed. Total Loss: 0.0659
#
# [INFO] Epoch 275/500
#  Epoch 275 completed. Total Loss: 0.0648
#
# [INFO] Epoch 276/500
#  Epoch 276 completed. Total Loss: 0.0653
#
# [INFO] Epoch 277/500
#  Epoch 277 completed. Total Loss: 0.0656
#
# [INFO] Epoch 278/500
#  Epoch 278 completed. Total Loss: 0.0655
#
# [INFO] Epoch 279/500
#  Epoch 279 completed. Total Loss: 0.0659
#
# [INFO] Epoch 280/500
#  Epoch 280 completed. Total Loss: 0.0662
#
# [INFO] Epoch 281/500
#  Epoch 281 completed. Total Loss: 0.0661
#
# [INFO] Epoch 282/500
#  Epoch 282 completed. Total Loss: 0.0661
#
# [INFO] Epoch 283/500
#  Epoch 283 completed. Total Loss: 0.0652
#
# [INFO] Epoch 284/500
#  Epoch 284 completed. Total Loss: 0.0650
#
# [INFO] Epoch 285/500
#  Epoch 285 completed. Total Loss: 0.0651
#
# [INFO] Epoch 286/500
#  Epoch 286 completed. Total Loss: 0.0649
#
# [INFO] Epoch 287/500
#  Epoch 287 completed. Total Loss: 0.0652
#
# [INFO] Epoch 288/500
#  Epoch 288 completed. Total Loss: 0.0647
#
# [INFO] Epoch 289/500
#  Epoch 289 completed. Total Loss: 0.0643
#
# [INFO] Epoch 290/500
#  Epoch 290 completed. Total Loss: 0.0646
#
# [INFO] Epoch 291/500
#  Epoch 291 completed. Total Loss: 0.0646
#
# [INFO] Epoch 292/500
#  Epoch 292 completed. Total Loss: 0.0648
#
# [INFO] Epoch 293/500
#  Epoch 293 completed. Total Loss: 0.0643
#
# [INFO] Epoch 294/500
#  Epoch 294 completed. Total Loss: 0.0651
#
# [INFO] Epoch 295/500
#  Epoch 295 completed. Total Loss: 0.0650
#
# [INFO] Epoch 296/500
#  Epoch 296 completed. Total Loss: 0.0640
#
# [INFO] Epoch 297/500
#  Epoch 297 completed. Total Loss: 0.0635
#
# [INFO] Epoch 298/500
#  Epoch 298 completed. Total Loss: 0.0644
#
# [INFO] Epoch 299/500
#  Epoch 299 completed. Total Loss: 0.0645
#
# [INFO] Epoch 300/500
#  Epoch 300 completed. Total Loss: 0.0636
#
# [INFO] Epoch 301/500
#  Epoch 301 completed. Total Loss: 0.0639
#
# [INFO] Epoch 302/500
#  Epoch 302 completed. Total Loss: 0.0641
#
# [INFO] Epoch 303/500
#  Epoch 303 completed. Total Loss: 0.0641
#
# [INFO] Epoch 304/500
#  Epoch 304 completed. Total Loss: 0.0639
#
# [INFO] Epoch 305/500
#  Epoch 305 completed. Total Loss: 0.0639
#
# [INFO] Epoch 306/500
#  Epoch 306 completed. Total Loss: 0.0645
#
# [INFO] Epoch 307/500
#  Epoch 307 completed. Total Loss: 0.0644
#
# [INFO] Epoch 308/500
#  Epoch 308 completed. Total Loss: 0.0638
#
# [INFO] Epoch 309/500
#  Epoch 309 completed. Total Loss: 0.0638
#
# [INFO] Epoch 310/500
#  Epoch 310 completed. Total Loss: 0.0637
#
# [INFO] Epoch 311/500
#  Epoch 311 completed. Total Loss: 0.0636
#
# [INFO] Epoch 312/500
#  Epoch 312 completed. Total Loss: 0.0637
#
# [INFO] Epoch 313/500
#  Epoch 313 completed. Total Loss: 0.0630
#
# [INFO] Epoch 314/500
#  Epoch 314 completed. Total Loss: 0.0628
#
# [INFO] Epoch 315/500
#  Epoch 315 completed. Total Loss: 0.0632
#
# [INFO] Epoch 316/500
#  Epoch 316 completed. Total Loss: 0.0629
#
# [INFO] Epoch 317/500
#  Epoch 317 completed. Total Loss: 0.0625
#
# [INFO] Epoch 318/500
#  Epoch 318 completed. Total Loss: 0.0631
#
# [INFO] Epoch 319/500
#  Epoch 319 completed. Total Loss: 0.0636
#
# [INFO] Epoch 320/500
#  Epoch 320 completed. Total Loss: 0.0637
#
# [INFO] Epoch 321/500
#  Epoch 321 completed. Total Loss: 0.0630
#
# [INFO] Epoch 322/500
#  Epoch 322 completed. Total Loss: 0.0626
#
# [INFO] Epoch 323/500
#  Epoch 323 completed. Total Loss: 0.0623
#
# [INFO] Epoch 324/500
#  Epoch 324 completed. Total Loss: 0.0636
#
# [INFO] Epoch 325/500
#  Epoch 325 completed. Total Loss: 0.0632
#
# [INFO] Epoch 326/500
#  Epoch 326 completed. Total Loss: 0.0629
#
# [INFO] Epoch 327/500
#  Epoch 327 completed. Total Loss: 0.0631
#
# [INFO] Epoch 328/500
#  Epoch 328 completed. Total Loss: 0.0626
#
# [INFO] Epoch 329/500
#  Epoch 329 completed. Total Loss: 0.0631
#
# [INFO] Epoch 330/500
#  Epoch 330 completed. Total Loss: 0.0630
#
# [INFO] Epoch 331/500
#  Epoch 331 completed. Total Loss: 0.0623
#
# [INFO] Epoch 332/500
#  Epoch 332 completed. Total Loss: 0.0628
#
# [INFO] Epoch 333/500
#  Epoch 333 completed. Total Loss: 0.0623
#
# [INFO] Epoch 334/500
#  Epoch 334 completed. Total Loss: 0.0627
#
# [INFO] Epoch 335/500
#  Epoch 335 completed. Total Loss: 0.0626
#
# [INFO] Epoch 336/500
#  Epoch 336 completed. Total Loss: 0.0621
#
# [INFO] Epoch 337/500
#  Epoch 337 completed. Total Loss: 0.0623
#
# [INFO] Epoch 338/500
#  Epoch 338 completed. Total Loss: 0.0620
#
# [INFO] Epoch 339/500
#  Epoch 339 completed. Total Loss: 0.0624
#
# [INFO] Epoch 340/500
#  Epoch 340 completed. Total Loss: 0.0625
#
# [INFO] Epoch 341/500
#  Epoch 341 completed. Total Loss: 0.0631
#
# [INFO] Epoch 342/500
#  Epoch 342 completed. Total Loss: 0.0619
#
# [INFO] Epoch 343/500
#  Epoch 343 completed. Total Loss: 0.0629
#
# [INFO] Epoch 344/500
#  Epoch 344 completed. Total Loss: 0.0617
#
# [INFO] Epoch 345/500
#  Epoch 345 completed. Total Loss: 0.0627
#
# [INFO] Epoch 346/500
#  Epoch 346 completed. Total Loss: 0.0621
#
# [INFO] Epoch 347/500
#  Epoch 347 completed. Total Loss: 0.0615
#
# [INFO] Epoch 348/500
#  Epoch 348 completed. Total Loss: 0.0615
#
# [INFO] Epoch 349/500
#  Epoch 349 completed. Total Loss: 0.0620
#
# [INFO] Epoch 350/500
#  Epoch 350 completed. Total Loss: 0.0614
#
# [INFO] Epoch 351/500
#  Epoch 351 completed. Total Loss: 0.0620
#
# [INFO] Epoch 352/500
#  Epoch 352 completed. Total Loss: 0.0613
#
# [INFO] Epoch 353/500
#  Epoch 353 completed. Total Loss: 0.0628
#
# [INFO] Epoch 354/500
#  Epoch 354 completed. Total Loss: 0.0615
#
# [INFO] Epoch 355/500
#  Epoch 355 completed. Total Loss: 0.0617
#
# [INFO] Epoch 356/500
#  Epoch 356 completed. Total Loss: 0.0616
#
# [INFO] Epoch 357/500
#  Epoch 357 completed. Total Loss: 0.0615
#
# [INFO] Epoch 358/500
#  Epoch 358 completed. Total Loss: 0.0617
#
# [INFO] Epoch 359/500
#  Epoch 359 completed. Total Loss: 0.0615
#
# [INFO] Epoch 360/500
#  Epoch 360 completed. Total Loss: 0.0617
#
# [INFO] Epoch 361/500
#  Epoch 361 completed. Total Loss: 0.0618
#
# [INFO] Epoch 362/500
#  Epoch 362 completed. Total Loss: 0.0608
#
# [INFO] Epoch 363/500
#  Epoch 363 completed. Total Loss: 0.0625
#
# [INFO] Epoch 364/500
#  Epoch 364 completed. Total Loss: 0.0613
#
# [INFO] Epoch 365/500
#  Epoch 365 completed. Total Loss: 0.0606
#
# [INFO] Epoch 366/500
#  Epoch 366 completed. Total Loss: 0.0611
#
# [INFO] Epoch 367/500
#  Epoch 367 completed. Total Loss: 0.0616
#
# [INFO] Epoch 368/500
#  Epoch 368 completed. Total Loss: 0.0610
#
# [INFO] Epoch 369/500
#  Epoch 369 completed. Total Loss: 0.0610
#
# [INFO] Epoch 370/500
#  Epoch 370 completed. Total Loss: 0.0604
#
# [INFO] Epoch 371/500
#  Epoch 371 completed. Total Loss: 0.0607
#
# [INFO] Epoch 372/500
#  Epoch 372 completed. Total Loss: 0.0610
#
# [INFO] Epoch 373/500
#  Epoch 373 completed. Total Loss: 0.0611
#
# [INFO] Epoch 374/500
#  Epoch 374 completed. Total Loss: 0.0617
#
# [INFO] Epoch 375/500
#  Epoch 375 completed. Total Loss: 0.0615
#
# [INFO] Epoch 376/500
#  Epoch 376 completed. Total Loss: 0.0612
#
# [INFO] Epoch 377/500
#  Epoch 377 completed. Total Loss: 0.0615
#
# [INFO] Epoch 378/500
#  Epoch 378 completed. Total Loss: 0.0608
#
# [INFO] Epoch 379/500
#  Epoch 379 completed. Total Loss: 0.0608
#
# [INFO] Epoch 380/500
#  Epoch 380 completed. Total Loss: 0.0611
#
# [INFO] Epoch 381/500
#  Epoch 381 completed. Total Loss: 0.0608
#
# [INFO] Epoch 382/500
#  Epoch 382 completed. Total Loss: 0.0607
#
# [INFO] Epoch 383/500
#  Epoch 383 completed. Total Loss: 0.0604
#
# [INFO] Epoch 384/500
#  Epoch 384 completed. Total Loss: 0.0608
#
# [INFO] Epoch 385/500
#  Epoch 385 completed. Total Loss: 0.0611
#
# [INFO] Epoch 386/500
#  Epoch 386 completed. Total Loss: 0.0603
#
# [INFO] Epoch 387/500
#  Epoch 387 completed. Total Loss: 0.0611
#
# [INFO] Epoch 388/500
#  Epoch 388 completed. Total Loss: 0.0601
#
# [INFO] Epoch 389/500
#  Epoch 389 completed. Total Loss: 0.0601
#
# [INFO] Epoch 390/500
#  Epoch 390 completed. Total Loss: 0.0601
#
# [INFO] Epoch 391/500
#  Epoch 391 completed. Total Loss: 0.0609
#
# [INFO] Epoch 392/500
#  Epoch 392 completed. Total Loss: 0.0607
#
# [INFO] Epoch 393/500
#  Epoch 393 completed. Total Loss: 0.0604
#
# [INFO] Epoch 394/500
#  Epoch 394 completed. Total Loss: 0.0597
#
# [INFO] Epoch 395/500
#  Epoch 395 completed. Total Loss: 0.0601
#
# [INFO] Epoch 396/500
#  Epoch 396 completed. Total Loss: 0.0599
#
# [INFO] Epoch 397/500
#  Epoch 397 completed. Total Loss: 0.0595
#
# [INFO] Epoch 398/500
#  Epoch 398 completed. Total Loss: 0.0598
#
# [INFO] Epoch 399/500
#  Epoch 399 completed. Total Loss: 0.0600
#
# [INFO] Epoch 400/500
#  Epoch 400 completed. Total Loss: 0.0598
#
# [INFO] Epoch 401/500
#  Epoch 401 completed. Total Loss: 0.0598
#
# [INFO] Epoch 402/500
#  Epoch 402 completed. Total Loss: 0.0611
#
# [INFO] Epoch 403/500
#  Epoch 403 completed. Total Loss: 0.0601
#
# [INFO] Epoch 404/500
#  Epoch 404 completed. Total Loss: 0.0597
#
# [INFO] Epoch 405/500
#  Epoch 405 completed. Total Loss: 0.0601
#
# [INFO] Epoch 406/500
#  Epoch 406 completed. Total Loss: 0.0595
#
# [INFO] Epoch 407/500
#  Epoch 407 completed. Total Loss: 0.0598
#
# [INFO] Epoch 408/500
#  Epoch 408 completed. Total Loss: 0.0594
#
# [INFO] Epoch 409/500
#  Epoch 409 completed. Total Loss: 0.0598
#
# [INFO] Epoch 410/500
#  Epoch 410 completed. Total Loss: 0.0596
#
# [INFO] Epoch 411/500
#  Epoch 411 completed. Total Loss: 0.0596
#
# [INFO] Epoch 412/500
#  Epoch 412 completed. Total Loss: 0.0597
#
# [INFO] Epoch 413/500
#  Epoch 413 completed. Total Loss: 0.0593
#
# [INFO] Epoch 414/500
#  Epoch 414 completed. Total Loss: 0.0593
#
# [INFO] Epoch 415/500
#  Epoch 415 completed. Total Loss: 0.0596
#
# [INFO] Epoch 416/500
#  Epoch 416 completed. Total Loss: 0.0595
#
# [INFO] Epoch 417/500
#  Epoch 417 completed. Total Loss: 0.0593
#
# [INFO] Epoch 418/500
#  Epoch 418 completed. Total Loss: 0.0599
#
# [INFO] Epoch 419/500
#  Epoch 419 completed. Total Loss: 0.0586
#
# [INFO] Epoch 420/500
#  Epoch 420 completed. Total Loss: 0.0600
#
# [INFO] Epoch 421/500
#  Epoch 421 completed. Total Loss: 0.0595
#
# [INFO] Epoch 422/500
#  Epoch 422 completed. Total Loss: 0.0592
#
# [INFO] Epoch 423/500
#  Epoch 423 completed. Total Loss: 0.0584
#
# [INFO] Epoch 424/500
#  Epoch 424 completed. Total Loss: 0.0597
#
# [INFO] Epoch 425/500
#  Epoch 425 completed. Total Loss: 0.0587
#
# [INFO] Epoch 426/500
#  Epoch 426 completed. Total Loss: 0.0586
#
# [INFO] Epoch 427/500
#  Epoch 427 completed. Total Loss: 0.0590
#
# [INFO] Epoch 428/500
#  Epoch 428 completed. Total Loss: 0.0587
#
# [INFO] Epoch 429/500
#  Epoch 429 completed. Total Loss: 0.0590
#
# [INFO] Epoch 430/500
#  Epoch 430 completed. Total Loss: 0.0586
#
# [INFO] Epoch 431/500
#  Epoch 431 completed. Total Loss: 0.0593
#
# [INFO] Epoch 432/500
#  Epoch 432 completed. Total Loss: 0.0584
#
# [INFO] Epoch 433/500
#  Epoch 433 completed. Total Loss: 0.0588
#
# [INFO] Epoch 434/500
#  Epoch 434 completed. Total Loss: 0.0592
#
# [INFO] Epoch 435/500
#  Epoch 435 completed. Total Loss: 0.0577
#
# [INFO] Epoch 436/500
#  Epoch 436 completed. Total Loss: 0.0590
#
# [INFO] Epoch 437/500
#  Epoch 437 completed. Total Loss: 0.0588
#
# [INFO] Epoch 438/500
#  Epoch 438 completed. Total Loss: 0.0588
#
# [INFO] Epoch 439/500
#  Epoch 439 completed. Total Loss: 0.0591
#
# [INFO] Epoch 440/500
#  Epoch 440 completed. Total Loss: 0.0588
#
# [INFO] Epoch 441/500
#  Epoch 441 completed. Total Loss: 0.0581
#
# [INFO] Epoch 442/500
#  Epoch 442 completed. Total Loss: 0.0581
#
# [INFO] Epoch 443/500
#  Epoch 443 completed. Total Loss: 0.0576
#
# [INFO] Epoch 444/500
#  Epoch 444 completed. Total Loss: 0.0582
#
# [INFO] Epoch 445/500
#  Epoch 445 completed. Total Loss: 0.0579
#
# [INFO] Epoch 446/500
#  Epoch 446 completed. Total Loss: 0.0588
#
# [INFO] Epoch 447/500
#  Epoch 447 completed. Total Loss: 0.0588
#
# [INFO] Epoch 448/500
#  Epoch 448 completed. Total Loss: 0.0588
#
# [INFO] Epoch 449/500
#  Epoch 449 completed. Total Loss: 0.0592
#
# [INFO] Epoch 450/500
#  Epoch 450 completed. Total Loss: 0.0586
#
# [INFO] Epoch 451/500
#  Epoch 451 completed. Total Loss: 0.0580
#
# [INFO] Epoch 452/500
#  Epoch 452 completed. Total Loss: 0.0589
#
# [INFO] Epoch 453/500
#  Epoch 453 completed. Total Loss: 0.0588
#
# [INFO] Epoch 454/500
#  Epoch 454 completed. Total Loss: 0.0600
#
# [INFO] Epoch 455/500
#  Epoch 455 completed. Total Loss: 0.0579
#
# [INFO] Epoch 456/500
#  Epoch 456 completed. Total Loss: 0.0586
#
# [INFO] Epoch 457/500
#  Epoch 457 completed. Total Loss: 0.0573
#
# [INFO] Epoch 458/500
#  Epoch 458 completed. Total Loss: 0.0592
#
# [INFO] Epoch 459/500
#  Epoch 459 completed. Total Loss: 0.0578
#
# [INFO] Epoch 460/500
#  Epoch 460 completed. Total Loss: 0.0580
#
# [INFO] Epoch 461/500
#  Epoch 461 completed. Total Loss: 0.0580
#
# [INFO] Epoch 462/500
#  Epoch 462 completed. Total Loss: 0.0580
#
# [INFO] Epoch 463/500
#  Epoch 463 completed. Total Loss: 0.0578
#
# [INFO] Epoch 464/500
#  Epoch 464 completed. Total Loss: 0.0577
#
# [INFO] Epoch 465/500
#  Epoch 465 completed. Total Loss: 0.0583
#
# [INFO] Epoch 466/500
#  Epoch 466 completed. Total Loss: 0.0581
#
# [INFO] Epoch 467/500
#  Epoch 467 completed. Total Loss: 0.0578
#
# [INFO] Epoch 468/500
#  Epoch 468 completed. Total Loss: 0.0578
#
# [INFO] Epoch 469/500
#  Epoch 469 completed. Total Loss: 0.0583
#
# [INFO] Epoch 470/500
#  Epoch 470 completed. Total Loss: 0.0575
#
# [INFO] Epoch 471/500
#  Epoch 471 completed. Total Loss: 0.0578
#
# [INFO] Epoch 472/500
#  Epoch 472 completed. Total Loss: 0.0576
#
# [INFO] Epoch 473/500
#  Epoch 473 completed. Total Loss: 0.0580
#
# [INFO] Epoch 474/500
#  Epoch 474 completed. Total Loss: 0.0582
#
# [INFO] Epoch 475/500
#  Epoch 475 completed. Total Loss: 0.0576
#
# [INFO] Epoch 476/500
#  Epoch 476 completed. Total Loss: 0.0575
#
# [INFO] Epoch 477/500
#  Epoch 477 completed. Total Loss: 0.0575
#
# [INFO] Epoch 478/500
#  Epoch 478 completed. Total Loss: 0.0577
#
# [INFO] Epoch 479/500
#  Epoch 479 completed. Total Loss: 0.0581
#
# [INFO] Epoch 480/500
#  Epoch 480 completed. Total Loss: 0.0581
#
# [INFO] Epoch 481/500
#  Epoch 481 completed. Total Loss: 0.0577
#
# [INFO] Epoch 482/500
#  Epoch 482 completed. Total Loss: 0.0572
#
# [INFO] Epoch 483/500
#  Epoch 483 completed. Total Loss: 0.0576
#
# [INFO] Epoch 484/500
#  Epoch 484 completed. Total Loss: 0.0568
#
# [INFO] Epoch 485/500
#  Epoch 485 completed. Total Loss: 0.0574
#
# [INFO] Epoch 486/500
#  Epoch 486 completed. Total Loss: 0.0575
#
# [INFO] Epoch 487/500
#  Epoch 487 completed. Total Loss: 0.0578
#
# [INFO] Epoch 488/500
#  Epoch 488 completed. Total Loss: 0.0574
#
# [INFO] Epoch 489/500
#  Epoch 489 completed. Total Loss: 0.0584
#
# [INFO] Epoch 490/500
#  Epoch 490 completed. Total Loss: 0.0572
#
# [INFO] Epoch 491/500
#  Epoch 491 completed. Total Loss: 0.0573
#
# [INFO] Epoch 492/500
#  Epoch 492 completed. Total Loss: 0.0574
#
# [INFO] Epoch 493/500
#  Epoch 493 completed. Total Loss: 0.0584
#
# [INFO] Epoch 494/500
#  Epoch 494 completed. Total Loss: 0.0571
#
# [INFO] Epoch 495/500
#  Epoch 495 completed. Total Loss: 0.0577
#
# [INFO] Epoch 496/500
#  Epoch 496 completed. Total Loss: 0.0575
#
# [INFO] Epoch 497/500
#  Epoch 497 completed. Total Loss: 0.0574
#
# [INFO] Epoch 498/500
#  Epoch 498 completed. Total Loss: 0.0577
#
# [INFO] Epoch 499/500
#  Epoch 499 completed. Total Loss: 0.0569
#
# [INFO] Epoch 500/500
#  Epoch 500 completed. Total Loss: 0.0572
# Training completed.

# %%
metrics = trainer.evaluate(X_train2, y_train)
print("Evaluation metrics:", metrics)
# Out:
# Evaluation metrics: {'MSE': 0.17573031111263346, 'MAE': 0.10512927919626236, 'R² Score': 0.02036154270172119}

# %%
# Predict on new data

predictions = trainer.predict(X_submission2)

submission_df['iv'] = predictions.flatten()  

combined_df = pd.concat([submission_df['iv'], test_df['iv']])
combined_df = combined_df.sort_index()

print(combined_df.head())
# Out:
# 0    0.280939
# 1    0.270276
# 2    0.243598
# 3    0.241888
# 4    0.235328
# Name: iv, dtype: float64
# /tmp/ipykernel_1058328/2418346176.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission_df['iv'] = predictions.flatten()

# %%
hhh = pd.read_csv("sample_submission.csv")

# Ensure combined_df has exactly 627380 rows (12065 * 52)
assert len(combined_df) == 12065 * 52, "combined_df does not have exactly 627380 rows."

# Define your column names
column_names = [
    'call_iv_24000', 'call_iv_24100', 'call_iv_24200', 'call_iv_24300', 'call_iv_24400',
    'call_iv_24500', 'call_iv_24600', 'call_iv_24700', 'call_iv_24800', 'call_iv_24900',
    'call_iv_25000', 'call_iv_25100', 'call_iv_25200', 'call_iv_25300', 'call_iv_25400',
    'call_iv_25500', 'call_iv_25600', 'call_iv_25700', 'call_iv_25800', 'call_iv_25900',
    'call_iv_26000', 'call_iv_26100', 'call_iv_26200', 'call_iv_26300', 'call_iv_26400',
    'call_iv_26500', 'put_iv_23000', 'put_iv_23100', 'put_iv_23200', 'put_iv_23300',
    'put_iv_23400', 'put_iv_23500', 'put_iv_23600', 'put_iv_23700', 'put_iv_23800',
    'put_iv_23900', 'put_iv_24000', 'put_iv_24100', 'put_iv_24200', 'put_iv_24300',
    'put_iv_24400', 'put_iv_24500', 'put_iv_24600', 'put_iv_24700', 'put_iv_24800',
    'put_iv_24900', 'put_iv_25000', 'put_iv_25100', 'put_iv_25200', 'put_iv_25300',
    'put_iv_25400', 'put_iv_25500'
]

# Reshape into (12065, 52)
reshaped_df = combined_df.values.reshape(52, 12065).T  # transpose to get (12065, 52)

# Create new DataFrame
final_df = pd.DataFrame(reshaped_df, columns=column_names)
final_df['timestamp'] = final_df.index

# Move 'timestamp' to the first column
final_df = final_df[["timestamp"] + [col for col in final_df.columns if col != "timestamp"]]

assert final_df.shape == hhh.shape, "final_df does not have the expected shape ."

# Save to CSV
final_df.to_csv("submission9_m2.csv", index=False)
